# %%
from pathlib import Path, PureWindowsPath

import matplotlib.pyplot as plt
import mne
import numpy as np
import pandas as pd
import scipy.io as sio
from mne import io

# %%
# %%capture 
data_folder = Path("/Users/peter/Google Drive/artifact-rejection-walker-lab/eeg-data/601/")
file_name = data_folder / "Rew_601_rest_bb_epoch.set"
path_on_windows = PureWindowsPath(file_name)
epochs = mne.io.read_epochs_eeglab(path_on_windows)
data = epochs.to_data_frame()
# reject_arr = sio.loadmat('Rew_601_rest_reject_rmm.mat')
# reject_key = reject_arr['reject'][0].tolist()

# %%
df = data.copy(); df = df.reset_index(); df = df.drop(['condition'], axis=1)
df_ = df.copy()

# %%
df_ = df_.drop(['epoch', 'time'], axis=1)
df_.head()
# Out:
# signal        C3         O2        C4         O1       Fp1       Fp2  \
# 0      -4.101171 -10.619266 -5.968149  -5.813361 -3.508248 -5.491191
# 1      -5.183039 -10.431769 -3.539983  -8.367174 -3.882948 -4.066828
# 2      -6.473076 -10.933600 -1.935451 -10.873877 -4.071187 -2.699850
# 3      -8.008626 -12.535002 -1.666145 -13.169887 -3.855127 -1.478360
# 4      -9.597174 -15.219418 -2.770913 -14.950358 -3.055052 -0.552566
#
# signal        F7        F3        FZ        F4        F8        T3        CZ  \
# 0      -1.441384 -3.682605 -2.841753 -4.446309 -5.157160 -2.072411 -4.743762
# 1      -4.127728 -5.510036 -2.712256 -2.731580 -2.581909 -3.432891 -4.891985
# 2      -6.066678 -7.127059 -2.933984 -1.392381 -0.504993 -4.636084 -5.402406
# 3      -6.764383 -8.324136 -3.599645 -0.666902  0.725579 -5.518118 -6.403526
# 4      -6.133142 -8.924362 -4.461777 -0.604117  0.986625 -5.916834 -7.707548
#
# signal        T4        T5         P3         PZ        P4        T6
# 0      -2.857092 -1.348035  -5.897866  -6.512607 -7.994251 -6.712998
# 1      -0.377738 -3.379942  -7.622222  -7.438750 -6.328388 -5.844828
# 2       1.354425 -5.225135  -9.510497  -8.706780 -5.507238 -5.669819
# 3       1.881818 -6.697570 -11.537941 -10.455081 -6.059763 -6.624831
# 4       1.181734 -7.626414 -13.436047 -12.517210 -8.015812 -8.737988
